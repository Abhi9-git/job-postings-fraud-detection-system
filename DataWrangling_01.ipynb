# %%
import pandas as pd

# %%
raw_data=pd.read_csv("fake_real_job_postings_3000x25.csv")

# %%
data=pd.read_csv("fake_real_job_postings_3000x25.csv")

# %%
data.head()
# Out:
#    job_id                    job_title  \
# 0       1            Software Engineer
# 1       2               Content Writer
# 2       3  Customer Support Specialist
# 3       4                 Data Analyst
# 4       5             Graphic Designer
#
#                                      job_description  \
# 0  We are looking for responsibilities fast-paced...
# 1  We are looking for required support experience...
# 2  We are looking for dynamic required fast-paced...
# 3  We are looking for collaboration skills suppor...
# 4  We are looking for team growth growth fast-pac...
#
#                                         requirements  \
# 0  Candidates should have dynamic team skills fas...
# 1  Candidates should have required team fast-pace...
# 2  Candidates should have preferred knowledge opp...
# 3  Candidates should have innovation team require...
# 4  Candidates should have experience preferred kn...
#
#                                             benefits company_name  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   job_id                     3000 non-null   int64
#  1   job_title                  3000 non-null   str
#  2   job_description            3000 non-null   str
#  3   requirements               3000 non-null   str
#  4   benefits                   3000 non-null   str
#  5   company_name               1528 non-null   str
#  6   company_profile            3000 non-null   str
#  7   industry                   3000 non-null   str
#  8   employment_type            3000 non-null   str
#  9   location                   3000 non-null   str
#  10  salary_range               3000 non-null   str
#  11  required_experience_years  3000 non-null   int64
#  12  education_level            3000 non-null   str
#  13  department                 3000 non-null   str
# ...

# %%
data.isnull().sum()
# Out:
# job_id                          0
# job_title                       0
# job_description                 0
# requirements                    0
# benefits                        0
# company_name                 1472
# company_profile                 0
# industry                        0
# employment_type                 0
# location                        0
# salary_range                    0
# required_experience_years       0
# education_level                 0
# department                      0
# posting_date                    0
# application_deadline            0
# contact_email                   0
# company_website              1472
# has_logo                        0
# num_open_positions              0
# job_function                    0
# telecommuting                   0
# fraud_reason                 1528
# text_length                     0
# is_fake                         0
# dtype: int64

# %%
(data.isnull().sum() / len(data)) * 100
# Out:
# job_id                        0.000000
# job_title                     0.000000
# job_description               0.000000
# requirements                  0.000000
# benefits                      0.000000
# company_name                 49.066667
# company_profile               0.000000
# industry                      0.000000
# employment_type               0.000000
# location                      0.000000
# salary_range                  0.000000
# required_experience_years     0.000000
# education_level               0.000000
# department                    0.000000
# posting_date                  0.000000
# application_deadline          0.000000
# contact_email                 0.000000
# company_website              49.066667
# has_logo                      0.000000
# num_open_positions            0.000000
# job_function                  0.000000
# telecommuting                 0.000000
# fraud_reason                 50.933333
# text_length                   0.000000
# ...

# %%
data["company_name"]
# Out:
# 0       Company_543
# 1       Company_192
# 2               NaN
# 3        Company_95
# 4               NaN
#            ...
# 2995    Company_159
# 2996            NaN
# 2997            NaN
# 2998            NaN
# 2999    Company_354
# Name: company_name, Length: 3000, dtype: str

# %%
data = data.drop(columns=[
    "job_id",
    "location",
    "application_deadline"
])

# %%
data.head()
# Out:
#                      job_title  \
# 0            Software Engineer
# 1               Content Writer
# 2  Customer Support Specialist
# 3                 Data Analyst
# 4             Graphic Designer
#
#                                      job_description  \
# 0  We are looking for responsibilities fast-paced...
# 1  We are looking for required support experience...
# 2  We are looking for dynamic required fast-paced...
# 3  We are looking for collaboration skills suppor...
# 4  We are looking for team growth growth fast-pac...
#
#                                         requirements  \
# 0  Candidates should have dynamic team skills fas...
# 1  Candidates should have required team fast-pace...
# 2  Candidates should have preferred knowledge opp...
# 3  Candidates should have innovation team require...
# 4  Candidates should have experience preferred kn...
#
#                                             benefits company_name  \
# ...

# %%
missing = data.isnull().sum().sort_values(ascending=False)
missing
# Out:
# fraud_reason                 1528
# company_name                 1472
# company_website              1472
# requirements                    0
# job_description                 0
# job_title                       0
# company_profile                 0
# benefits                        0
# industry                        0
# employment_type                 0
# education_level                 0
# department                      0
# salary_range                    0
# required_experience_years       0
# contact_email                   0
# posting_date                    0
# num_open_positions              0
# has_logo                        0
# job_function                    0
# telecommuting                   0
# text_length                     0
# is_fake                         0
# dtype: int64

# %%
missing_summary = pd.DataFrame({
    "Missing Values": data.isnull().sum(),
    "Percentage": (data.isnull().sum() / len(data)) * 100
})

missing_summary.sort_values(by="Percentage", ascending=False)
# Out:
#                            Missing Values  Percentage
# fraud_reason                         1528   50.933333
# company_name                         1472   49.066667
# company_website                      1472   49.066667
# requirements                            0    0.000000
# job_description                         0    0.000000
# job_title                               0    0.000000
# company_profile                         0    0.000000
# benefits                                0    0.000000
# industry                                0    0.000000
# employment_type                         0    0.000000
# education_level                         0    0.000000
# department                              0    0.000000
# salary_range                            0    0.000000
# required_experience_years               0    0.000000
# contact_email                           0    0.000000
# posting_date                            0    0.000000
# ...

# %%
data.head(20)
# Out:
#                       job_title  \
# 0             Software Engineer
# 1                Content Writer
# 2   Customer Support Specialist
# 3                  Data Analyst
# 4              Graphic Designer
# 5             Marketing Manager
# 6                Content Writer
# 7   Customer Support Specialist
# 8             Marketing Manager
# 9              Business Analyst
# 10  Customer Support Specialist
# 11             Graphic Designer
# 12               HR Coordinator
# 13              Product Manager
# 14                 Data Analyst
# 15               HR Coordinator
# 16            Marketing Manager
# 17            Software Engineer
# 18            Software Engineer
# 19             Business Analyst
#
#                                       job_description  \
# 0   We are looking for responsibilities fast-paced...
# 1   We are looking for required support experience...
# 2   We are looking for dynamic required fast-paced...
# ...

# %%
pd.crosstab(
    data["company_name"].isnull(),
    data["is_fake"]
)
# Out:
# is_fake          0     1
# company_name
# False         1528     0
# True             0  1472

# %%
pd.crosstab(
    data["company_website"].isnull(),
    data["is_fake"]
)
# Out:
# is_fake             0     1
# company_website
# False            1528     0
# True                0  1472

# %%
pd.crosstab(
    data["has_logo"],
    data["is_fake"]
)
# Out:
# is_fake     0     1
# has_logo
# 0         790  1472
# 1         738     0

# %%
data = data.drop(columns=[
    "fraud_reason",
    "company_name",
    "company_website"
])

# %%
data.head(10)
# Out:
#                      job_title  \
# 0            Software Engineer
# 1               Content Writer
# 2  Customer Support Specialist
# 3                 Data Analyst
# 4             Graphic Designer
# 5            Marketing Manager
# 6               Content Writer
# 7  Customer Support Specialist
# 8            Marketing Manager
# 9             Business Analyst
#
#                                      job_description  \
# 0  We are looking for responsibilities fast-paced...
# 1  We are looking for required support experience...
# 2  We are looking for dynamic required fast-paced...
# 3  We are looking for collaboration skills suppor...
# 4  We are looking for team growth growth fast-pac...
# 5  We are looking for knowledge development exper...
# 6  We are looking for knowledge team fast-paced d...
# 7  We are looking for responsibilities innovation...
# 8  We are looking for opportunity team collaborat...
# 9  We are looking for responsibilities dynamic de...
#
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.select_dtypes(include="string").columns
# Out:
# Index(['job_title', 'job_description', 'requirements', 'benefits',
#        'company_profile', 'industry', 'employment_type', 'salary_range',
#        'education_level', 'department', 'posting_date', 'contact_email',
#        'job_function'],
#       dtype='str')

# %%
data["employment_type"].unique()
# Out:
# <StringArray>
# ['Contract', 'Full-time', 'Internship', 'Part-time', 'Temporary']
# Length: 5, dtype: str

# %%
data['job_title'].unique()
# Out:
# <StringArray>
# [          'Software Engineer',              'Content Writer',
#  'Customer Support Specialist',                'Data Analyst',
#             'Graphic Designer',           'Marketing Manager',
#             'Business Analyst',              'HR Coordinator',
#              'Product Manager',             'Sales Executive']
# Length: 10, dtype: str

# %%
data["application_deadline"] = raw_data["application_deadline"]

# %%
data.head(10)
# Out:
#                      job_title  \
# 0            Software Engineer
# 1               Content Writer
# 2  Customer Support Specialist
# 3                 Data Analyst
# 4             Graphic Designer
# 5            Marketing Manager
# 6               Content Writer
# 7  Customer Support Specialist
# 8            Marketing Manager
# 9             Business Analyst
#
#                                      job_description  \
# 0  We are looking for responsibilities fast-paced...
# 1  We are looking for required support experience...
# 2  We are looking for dynamic required fast-paced...
# 3  We are looking for collaboration skills suppor...
# 4  We are looking for team growth growth fast-pac...
# 5  We are looking for knowledge development exper...
# 6  We are looking for knowledge team fast-paced d...
# 7  We are looking for responsibilities innovation...
# 8  We are looking for opportunity team collaborat...
# 9  We are looking for responsibilities dynamic de...
#
# ...

# %%
categorical_cols = data.select_dtypes(include="str").columns

print(categorical_cols)
# Out:
# Index(['job_title', 'job_description', 'requirements', 'benefits',
#        'company_profile', 'industry', 'employment_type', 'salary_range',
#        'education_level', 'department', 'posting_date', 'contact_email',
#        'job_function', 'application_deadline'],
#       dtype='str')

# %%
data["employment_type"].value_counts(dropna=False)
# Out:
# employment_type
# Part-time     615
# Full-time     614
# Internship    605
# Contract      598
# Temporary     568
# Name: count, dtype: int64

# %%
data["education_level"].value_counts(dropna=False)
# Out:
# education_level
# Bachelor       793
# Master         752
# PhD            737
# High School    718
# Name: count, dtype: int64

# %%
data["posting_date"] = pd.to_datetime(data["posting_date"])
data["application_deadline"] = pd.to_datetime(data["application_deadline"])

# %%
data["posting_date"].dt.year
data["posting_date"].dt.month
data["posting_date"].dt.day_name()
# Out:
# 0         Friday
# 1         Friday
# 2         Monday
# 3         Monday
# 4       Saturday
#           ...
# 2995      Sunday
# 2996      Sunday
# 2997      Sunday
# 2998     Tuesday
# 2999     Tuesday
# Name: posting_date, Length: 3000, dtype: str

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   job_title                  3000 non-null   str
#  1   job_description            3000 non-null   str
#  2   requirements               3000 non-null   str
#  3   benefits                   3000 non-null   str
#  4   company_profile            3000 non-null   str
#  5   industry                   3000 non-null   str
#  6   employment_type            3000 non-null   str
#  7   salary_range               3000 non-null   str
#  8   required_experience_years  3000 non-null   int64
#  9   education_level            3000 non-null   str
#  10  department                 3000 non-null   str
#  11  posting_date               3000 non-null   datetime64[us]
#  12  contact_email              3000 non-null   str
#  13  has_logo                   3000 non-null   int64
# ...

# %%
(data["application_deadline"] < data["posting_date"]).sum()
# Out:
# np.int64(0)

# %%
data.to_csv("/home/abhinav/Desktop/Fk_Jb_Detection project/CleanData.csv")
